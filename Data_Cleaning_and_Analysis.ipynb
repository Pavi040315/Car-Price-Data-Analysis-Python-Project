# %% [markdown]
# # Task 3:  Data Cleaning & Data Processing

# %%
# Import pandas library

import pandas as pd

# %%
# Load and display the car_prices dataset

df = pd.read_csv("car_prices.csv")
df
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0   white
# ...

# %%
# Return uniques from the column 'seller' 

df.seller.unique()
# Out:
# array(['kia motors america  inc',
#        'financial services remarketing (lease)',
#        'volvo na rep/world omni', ..., 'maserati north america inc',
#        'alternative financial group inc', 'i -5 uhlmann rv'], dtype=object)

# %%
# Return number of uniques from the column 'seller' before cleaning the column

df.seller.nunique()
# Out:
# 14263

# %%
# Replace '-' with ' '(whitespace) e.g.'nissan-infiniti lt' replace with 'nissan-infiniti lt'

df.seller = df.seller.str.replace("-", " ").str.replace("  ", " ")  
df
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0   white
# ...

# %%
# Return number of uniques from the column 'seller' after cleaning the column

df.seller.nunique()
# Out:
# 14243

# %%
# Discover duplicates

df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 558832    False
# 558833    False
# 558834    False
# 558835    False
# 558836    False
# Length: 558837, dtype: bool

# %%
# Discover number of duplicates

df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# No duplicates have been found

# %%
# Discover empty cells

df.isnull()
# Out:
#          year   make  model   trim   body  transmission    vin  state  \
# 0       False  False  False  False  False         False  False  False
# 1       False  False  False  False  False         False  False  False
# 2       False  False  False  False  False         False  False  False
# 3       False  False  False  False  False         False  False  False
# 4       False  False  False  False  False         False  False  False
# ...       ...    ...    ...    ...    ...           ...    ...    ...
# 558832  False  False  False  False  False          True  False  False
# 558833  False  False  False  False  False         False  False  False
# 558834  False  False  False  False  False         False  False  False
# 558835  False  False  False  False  False         False  False  False
# 558836  False  False  False  False  False         False  False  False
#
#         condition  odometer  color  interior  seller    mmr  sellingprice  \
# ...

# %%
# Discover number of empty cells

df.isnull().sum()
# Out:
# year                0
# make            10301
# model           10399
# trim            10651
# body            13195
# transmission    65352
# vin                 4
# state               0
# condition       11820
# odometer           94
# color             749
# interior          749
# seller              0
# mmr                38
# sellingprice       12
# saledate           12
# dtype: int64

# %%
# Remove rows that contain empty cells and write in the same DataFrame

df.dropna(inplace = True)
df
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558831  2011     BMW             5 Series         528i      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer  color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0  white
# ...

# %%
# Check whether have any empty cells

df.isnull().sum()
# Out:
# year            0
# make            0
# model           0
# trim            0
# body            0
# transmission    0
# vin             0
# state           0
# condition       0
# odometer        0
# color           0
# interior        0
# seller          0
# mmr             0
# sellingprice    0
# saledate        0
# dtype: int64

# %% [markdown]
# Dataset has been cleaned as the empty cells have been dropped and no duplicates found.

# %% [markdown]
# ## Task 4: Data Analysis

# %% [markdown]
# ## a. The general information about the entire data set car_prices.csv

# %%
# The first n records

df.head()
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
# 3  yv1612tb4f1310987    ca       41.0   14282.0  white    black
# 4  wba6b2c57ed129731    ca       43.0    2641.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                  kia motors america inc  20500.0       21500.0
# ...

# %%
# The last n records

df.tail()
# Out:
#         year    make     model         trim       body transmission  \
# 558831  2011     BMW  5 Series         528i      Sedan    automatic
# 558833  2012     Ram      2500  Power Wagon   Crew Cab    automatic
# 558834  2012     BMW        X5    xDrive35d        SUV    automatic
# 558835  2015  Nissan    Altima        2.5 S      sedan    automatic
# 558836  2014    Ford     F-150          XLT  SuperCrew    automatic
#
#                       vin state  condition  odometer  color interior  \
# 558831  wbafr1c53bc744672    fl       39.0   66403.0  white    brown
# 558833  3c6td5et6cg112407    wa        5.0   54393.0  white    black
# 558834  5uxzw0c58cl668465    ca       48.0   50561.0  black    black
# 558835  1n4al3ap0fc216050    ga       38.0   16658.0  white    black
# 558836  1ftfw1et2eke87277    ca       34.0   15008.0   gray     gray
#
#                                                    seller      mmr  \
# 558831           lauderdale imports ltd bmw pembrok pines  20300.0
# ...

# %%
# Random n records

df.sample()
# Out:
#         year  make  model trim   body transmission                vin state  \
# 298577  2000  Ford  Focus   SE  Sedan    automatic  1fafp3436yw298242    nc
#
#         condition  odometer color interior               seller     mmr  \
# 298577       19.0  154941.0  gold    beige  crossroads ford inc  1125.0
#
#         sellingprice                                 saledate
# 298577        1500.0  Mon Feb 16 2015 00:31:00 GMT-0800 (PST)

# %%
# The dimension of dataset, e.g shape

df.shape
# Out:
# (472325, 16)

# %%
# The column labels of dataset

df.columns
# Out:
# Index(['year', 'make', 'model', 'trim', 'body', 'transmission', 'vin', 'state',
#        'condition', 'odometer', 'color', 'interior', 'seller', 'mmr',
#        'sellingprice', 'saledate'],
#       dtype='object')

# %%
# General information about data types of datasets

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 472325 entries, 0 to 558836
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          472325 non-null  int64
#  1   make          472325 non-null  object
#  2   model         472325 non-null  object
#  3   trim          472325 non-null  object
#  4   body          472325 non-null  object
#  5   transmission  472325 non-null  object
#  6   vin           472325 non-null  object
#  7   state         472325 non-null  object
#  8   condition     472325 non-null  float64
#  9   odometer      472325 non-null  float64
#  10  color         472325 non-null  object
#  11  interior      472325 non-null  object
#  12  seller        472325 non-null  object
#  13  mmr           472325 non-null  float64
#  14  sellingprice  472325 non-null  float64
#  15  saledate      472325 non-null  object
# dtypes: float64(4), int64(1), object(11)
# memory usage: 61.3+ MB

# %%
# Shows datatype of each column of dataset

df.dtypes
# Out:
# year              int64
# make             object
# model            object
# trim             object
# body             object
# transmission     object
# vin              object
# state            object
# condition       float64
# odometer        float64
# color            object
# interior         object
# seller           object
# mmr             float64
# sellingprice    float64
# saledate         object
# dtype: object

# %%
# Descriptive statistics for numeric columns

df.describe()   #This only work for numeric/discrete data type
# Out:
#                 year      condition       odometer            mmr  \
# count  472325.000000  472325.000000  472325.000000  472325.000000
# mean     2010.210980      30.774177   66701.732040   13837.058964
# std         3.822151      13.286866   51939.586894    9532.229273
# min      1990.000000       1.000000       1.000000      25.000000
# 25%      2008.000000      24.000000   28137.000000    7425.000000
# 50%      2012.000000      35.000000   51085.000000   12300.000000
# 75%      2013.000000      41.000000   96590.000000   18300.000000
# max      2015.000000      49.000000  999999.000000  182000.000000
#
#         sellingprice
# count  472325.000000
# mean    13690.512058
# std      9613.033738
# min         1.000000
# 25%      7200.000000
# 50%     12200.000000
# 75%     18200.000000
# max    230000.000000

# %%
# Descriptive statistics for non-numeric columns

df.describe(include='object')
# Out:
#           make   model    trim    body transmission                vin  \
# count   472325  472325  472325  472325       472325             472325
# unique      53     768    1494      85            2             465768
# top       Ford  Altima    Base   Sedan    automatic  wp0ca2988xu629622
# freq     81013   16346   48779  174647       455963                  4
#
#          state   color interior              seller  \
# count   472325  472325   472325              472325
# unique      34      20       17               11906
# top         fl   black    black  nissan infiniti lt
# freq     75243   93244   209865               25127
#
#                                        saledate
# count                                    472325
# unique                                     3609
# top     Tue Feb 10 2015 01:30:00 GMT-0800 (PST)
# freq                                       5004

# %%
df.seller.value_counts(dropna=False)
# Out:
# seller
# nissan infiniti lt                      25127
# ford motor credit company llc           17756
# the hertz corporation                   16286
# santander consumer                      14245
# avis corporation                        11471
#                                         ...
# coulter cadillac oldsmobile inc             1
# t3 auto & rec llc                           1
# apple acura subaru                          1
# snyders auto sales & car care center        1
# i 5 uhlmann rv                              1
# Name: count, Length: 11906, dtype: int64

# %%
df.groupby(['make','transmission']).size()
# Out:
# make          transmission
# Acura         automatic       4340
#               manual           163
# Aston Martin  automatic         19
#               manual             5
# Audi          automatic       4459
#                               ...
# Volkswagen    automatic       9636
#               manual          1144
# Volvo         automatic       3036
#               manual            46
# smart         automatic        343
# Length: 95, dtype: int64

# %% [markdown]
# ## b. Find the most expensive car with details of make, model, seller and selling price.

# %%
# Find the expensive car and display make, model, seller and sellingprice

expensive_car = df[['make', 'model','seller','sellingprice']].loc[max]
expensive_car
# Out:
# make                                   Ford
# model                                Escape
# seller          ford lincoln dealer program
# sellingprice                       230000.0
# Name: 344905, dtype: object

# %% [markdown]
# The most expensive car is Ford Escape from Ford-Lincoln Dealer Program which is RM 344905.

# %% [markdown]
# ## c. Find the number cars sold in each model of BMW

# %%
# Groupby 'BMW' make and model cars with additional column named'Total_num_of_car_sold'

BMW = df[df['make'] == 'BMW'].groupby(['make', 'model']).size().reset_index(name='Total_num_of_cars_sold')
BMW
# Out:
#    make                  model  Num_of_cars_sold
# 0   BMW               1 Series               363
# 1   BMW               2 Series                32
# 2   BMW               3 Series              7132
# 3   BMW  3 Series Gran Turismo                71
# 4   BMW               4 Series               275
# 5   BMW    4 Series Gran Coupe                11
# 6   BMW               5 Series              3479
# 7   BMW  5 Series Gran Turismo               164
# 8   BMW               6 Series               603
# 9   BMW    6 Series Gran Coupe                90
# 10  BMW               7 Series              1064
# 11  BMW               8 Series                 1
# 12  BMW         ActiveHybrid 5                 2
# 13  BMW         ActiveHybrid 7                13
# 14  BMW        ActiveHybrid X6                 5
# 15  BMW                      M                 7
# 16  BMW                     M3               251
# 17  BMW                     M4                 9
# ...

# %% [markdown]
# ## d. Find the total number of cars sold in 2000

# %%
# Groupby total number of cars sold in year 2000

cars_sold_in_2000 = df[df['year'] == 2000].groupby('year').size().reset_index(name = 'number_of_cars_sold')
cars_sold_in_2000
# Out:
#    year  number_of_cars_sold
# 0  2000                 3427

# %% [markdown]
# ## e. Do additional EDA steps to explain your problem definition in detail.

# %%
# Correlation between year and sellingprice

#dfno = pd.read_csv("car_prices.csv",usecols = (0,14))
dfno.corr()
# Out:
#                  year  sellingprice
# year          1.00000       0.58648
# sellingprice  0.58648       1.00000

# %% [markdown]
# #### (i)Top 5 Car Models Sold

# %%
# Top 5 Car Models Sold with additional column'Total_number_of_cars_sold'

top_model = df.model.value_counts().head(5).reset_index(name = 'Total_number_of_cars_sold')
top_model
# Out:
#     model  Total_number_of_cars_sold
# 0  Altima                      19349
# 1   F-150                      14479
# 2  Fusion                      12946
# 3   Camry                      12545
# 4  Escape                      11861

# %% [markdown]
# #### (ii) Total Number Of Cars Sold According to Their Transmission

# %%
# Total number of cars sold According to their transmission excluding 'sedan' and 'Sedan' from the column

prefer_transmission = df.transmission.value_counts().reset_index(name = 'Total_number_of_cars_sold')
prefer_transmission = prefer_transmission[(prefer_transmission['transmission'] != 'sedan') & (prefer['transmission'] != 'Sedan')]
prefer_transmission
# Out:
#   transmission  Total_number_of_cars_sold
# 0    automatic                     475915
# 1       manual                      17544

# %% [markdown]
# #### (iii)Top 5 Car Makes

# %%
# Top 5 car makes with additional column 'Total_number_of_cars_sold'

top_make = df.make.value_counts().head(5).reset_index(name = "Total_number_of_cars_sold")
top_make
# Out:
#         make  Total_number_of_cars_sold
# 0       Ford                      93554
# 1  Chevrolet                      60197
# 2     Nissan                      53946
# 3     Toyota                      39871
# 4      Dodge                      30710

# %% [markdown]
# ## Task 5: Create the visuals using Matplotlib or Bokeh

# %% [markdown]
# ### a. Choose the suitable type of chart to plot an interactive chart for the number of cars sold over year after 2000.

# %%
# Interactive Horizontal Bar Chart
import pandas as pd
import matplotlib.pyplot as plt

# Interactive visualization
# %matplotlib notebook
df = pd.read_csv("car_prices.csv")
all_year = df.groupby('year').size().reset_index(name = 'number_of_cars_sold')
year_greater_2000 = all_year[all_year['year'] > 2000].reset_index()

fig = plt.subplots(figsize =(10, 5)) # Change the dimension of the plot
x = year_greater_2000.year
y = year_greater_2000.number_of_cars_sold
plt.title("Total Number Of Cars Sold Over Year After 2000") # Title
plt.xlabel("Number of cars sold") # x-axis label
plt.ylabel("Year") # y-axis label
plt.xticks(range(0,120000,10000))
plt.yticks(range(2001,2016,1))
plt.barh(x,y, color='greenyellow') # color change
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1124.3999463844325">

# %% [markdown]
# ### b. Choose the suitable type of chart to plot an interactive chart for the top 10 seller to their total selling price.

# %%
#Bar chart & Scatterplot - HoverTool
import pandas as pd
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import HoverTool

# Read data from data set
df = pd.read_csv("car_prices.csv")
df.seller = df.seller.str.replace("-", " ").str.replace("  ", " ")
grouped_seller = df.groupby('seller')['sellingprice'].sum().reset_index().sort_values(by='sellingprice', ascending=False).head(10)

x=grouped_seller.seller
y=grouped_seller.sellingprice


p=figure(x_range=x, width=900, height=600, toolbar_location='right')
# plot a bar chart
p.vbar(x, top= y,width=0.3, color='limegreen')
#p.scatter(x= x, y= y)

p.title.text="Total Number Of Cars Sold Over Year After 2000"
p.title.align="center"
p.xaxis.axis_label = "Seller"
p.yaxis.axis_label = "Selling Price"

p.xaxis.major_label_orientation = 45
p.scatter(x= x, y= y,fill_color="white", size=10)

# Create a hover tool called hover
hover = HoverTool(tooltips=[ ('Seller', '@x'), ('Selling Price','@y')])

# Add the hover tool to the plot
p.add_tools(hover)

# show the results
output_notebook()
show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="d1650d7b-3460-495b-93ea-183817bca34d">Loading BokehJS ...</span>
#     </div>
#   <div id="b9a57453-9728-4bd1-a8bb-1606bc68229b" data-root-id="p4349" style="display: contents;"></div>

# %% [markdown]
# ### c. Plot multiple graphs to explain your problem definition in detail.

# %% [markdown]
# #### (i)Top 5 Car Models Sold

# %%
#Bar chart & Scatterplot - HoverTool
import pandas as pd
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import HoverTool

# Read data from data set
df = pd.read_csv("car_prices.csv")
top_model = df.model.value_counts().head(5).reset_index(name = 'Total_number_of_cars_sold')

x=top_model.model
y=top_model.Total_number_of_cars_sold


p=figure(x_range=x, width=900, height=570, toolbar_location='right')
# plot a bar chart
p.vbar(x, top= y,width=0.3, color='pink')
#p.scatter(x= x, y= y)

p.title.text="Top 5 Car Models Sold"
p.title.align="center"
p.xaxis.axis_label = "Car Model"
p.yaxis.axis_label = "Total Number of Cars Sold"

p.xaxis.major_label_orientation = 45
p.scatter(x= x, y= y,fill_color="white", size=10)

# Create a hover tool called hover
hover = HoverTool(tooltips=[ ('Car Model', '@x'), ('Total Number of Cars Sold','@y')])

# Add the hover tool to the plot
p.add_tools(hover)

# show the results
output_notebook()
show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c047a6c8-a969-49ec-9e38-521a518779de">Loading BokehJS ...</span>
#     </div>
#   <div id="ed7e3302-571e-45e3-b84b-45b3364c63f2" data-root-id="p4511" style="display: contents;"></div>

# %% [markdown]
# #### (ii) Total Number Of Cars Sold According to Their Transmission

# %%
#Bar chart & Scatterplot - HoverTool
import pandas as pd
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import HoverTool

# Read data from data set
df = pd.read_csv("car_prices.csv")
prefer_transmission = df.transmission.value_counts().reset_index(name = 'Total_number_of_cars_sold')
prefer_transmission = prefer_transmission[(prefer_transmission['transmission'] != 'sedan') & (prefer['transmission'] != 'Sedan')]

# Set x axis and y axis variables
x=prefer_transmission.transmission
y=prefer_transmission.Total_number_of_cars_sold

name = 'number_of_cars_sold'
p=figure(x_range=x, width=800, height=500, toolbar_location='right')
# plot a bar chart
p.vbar(x, top= y,width=0.3, color='red')
#p.scatter(x= x, y= y)

p.title.text="Total Number Of Cars Sold According to Their Transmission"
p.title.align="center"
p.xaxis.axis_label = "Transmission"
p.yaxis.axis_label = "Cars Sold"

p.xaxis.major_label_orientation = 45
plt.yticks(range(0,550000,10000))
p.scatter(x= x, y= y,fill_color="white", size=10)

# Create a hover tool called hover
hover = HoverTool(tooltips=[ ('Transmission', '@x'), ('Cars Sold','@y')])

# Add the hover tool to the plot
p.add_tools(hover)

# show the results
output_notebook()
show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="d048429f-159d-4ae2-a677-6348410cdaab">Loading BokehJS ...</span>
#     </div>
#   <div id="ec4681bd-cb89-4e48-9f5c-ee1d4a4b4bf5" data-root-id="p4241" style="display: contents;"></div>

# %% [markdown]
# #### (iii)Top 5 Car Makes

# %%
# Interactive Horizontal Bar Chart
import pandas as pd
import matplotlib.pyplot as plt

# Interactive visualization
# %matplotlib notebook
df = pd.read_csv("car_prices.csv")
top_make = df.make.value_counts().head(5).reset_index(name = "Total_number_of_cars_sold")

fig = plt.subplots(figsize =(10, 5)) # Change the dimension of the plot
x = top_make.make
y = top_make.Total_number_of_cars_sold

plt.title("Top 5 Car Makes") # Title
plt.xlabel("Make") # x-axis label
plt.ylabel("Total Number of Cars Sold") # y-axis label
plt.xticks(range(0,6,1))
plt.yticks(range(0,110000,10000))
plt.bar(x,y, color='lightblue') # color change
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1124.3999463844325">
